# %% [markdown]
# ## Assignment 3 : Write a program to solve N-Queen problem using Genetic algorithm/ Evolutionary program.

# %%
import random

def random_chromosome(size): #making random chromosomes 
    return [ random.randint(1, nq) for _ in range(nq) ]

# %%
def fitness(chromosome):
    horizontal_collisions = sum([chromosome.count(queen)-1 for queen in chromosome])/2
    diagonal_collisions = 0

    n = len(chromosome)
    left_diagonal = [0] * 2*n
    right_diagonal = [0] * 2*n
    for i in range(n):
        left_diagonal[i + chromosome[i] - 1] += 1
        right_diagonal[len(chromosome) - i + chromosome[i] - 2] += 1

    diagonal_collisions = 0
    for i in range(2*n-1):
        counter = 0
        if left_diagonal[i] > 1:
            counter += left_diagonal[i]-1
        if right_diagonal[i] > 1:
            counter += right_diagonal[i]-1
        diagonal_collisions += counter / (n-abs(i-n+1))
    
    return int(maxFitness - (horizontal_collisions + diagonal_collisions)) #28-(2+3)=23

# %%
def probability(chromosome, fitness):
    return fitness(chromosome) / maxFitness

# %%
def random_pick(population, probabilities):
    populationWithProbabilty = zip(population, probabilities)
    total = sum(w for c, w in populationWithProbabilty)
    r = random.uniform(0, total)
    upto = 0
    for c, w in zip(population, probabilities):
        if upto + w >= r:
            return c
        upto += w
    assert False, "Shouldn't get here"

# %%
def reproduce(x, y): #doing cross_over between two chromosomes
    n = len(x)
    c = random.randint(0, n - 1)
    return x[0:c] + y[c:n]

# %%
def mutate(x):  #randomly changing the value of a random index of a chromosome
    n = len(x)
    c = random.randint(0, n - 1)
    m = random.randint(1, n)
    x[c] = m
    return x

# %%
def genetic_queen(population, fitness):
    mutation_probability = 0.03
    new_population = []
    probabilities = [probability(n, fitness) for n in population]
    for i in range(len(population)):
        x = random_pick(population, probabilities) #best chromosome 1
        y = random_pick(population, probabilities) #best chromosome 2
        child = reproduce(x, y) #creating two new chromosomes from the best 2 chromosomes
        if random.random() < mutation_probability:
            child = mutate(child)
        print_chromosome(child)
        new_population.append(child)
        if fitness(child) == maxFitness: break
    return new_population

# %%
def print_chromosome(chrom):
    print("Chromosome = {},  Fitness = {}"
        .format(str(chrom), fitness(chrom)))

# %%
if __name__ == "__main__":
    nq = int(input("Enter Number of Queens: ")) #say N = 8
    maxFitness = (nq*(nq-1))/2  # 8*7/2 = 28
    population = [random_chromosome(nq) for _ in range(100)]
    
    generation = 1

    while not maxFitness in [fitness(chrom) for chrom in population]:
        print("=== Generation {} ===".format(generation))
        population = genetic_queen(population, fitness)
        print("")
        print("Maximum Fitness = {}".format(max([fitness(n) for n in population])))
        generation += 1
    chrom_out = []
    print("Solved in Generation {}!".format(generation-1))
    for chrom in population:
        if fitness(chrom) == maxFitness:
            print("");
            print("One of the solutions: ")
            chrom_out = chrom
            print_chromosome(chrom)
            
    board = []

    for x in range(nq):
        board.append(["x"] * nq)
        
    for i in range(nq):
        board[nq-chrom_out[i]][i]="Q"
            

    def print_board(board):
        for row in board:
            print (" ".join(row))
            
    print()
    print_board(board)
# Out:
# Enter Number of Queens: 5
# === Generation 1 ===
# Chromosome = [1, 5, 5, 4, 4],  Fitness = 7
# Chromosome = [4, 2, 2, 1, 1],  Fitness = 7
# Chromosome = [4, 1, 4, 1, 4],  Fitness = 5
# Chromosome = [4, 5, 3, 2, 1],  Fitness = 9
# Chromosome = [1, 1, 1, 3, 3],  Fitness = 5
# Chromosome = [4, 2, 5, 2, 2],  Fitness = 7
# Chromosome = [4, 2, 5, 1, 1],  Fitness = 8
# Chromosome = [4, 4, 3, 5, 3],  Fitness = 7
# Chromosome = [2, 5, 5, 4, 4],  Fitness = 7
# Chromosome = [1, 4, 4, 5, 1],  Fitness = 7
# Chromosome = [5, 1, 4, 2, 4],  Fitness = 8
# Chromosome = [3, 4, 4, 1, 5],  Fitness = 8
# Chromosome = [1, 3, 4, 5, 4],  Fitness = 8
# Chromosome = [2, 2, 2, 4, 2],  Fitness = 3
# Chromosome = [2, 2, 1, 4, 4],  Fitness = 7
# Chromosome = [2, 2, 1, 4, 5],  Fitness = 8
# Chromosome = [1, 2, 2, 5, 3],  Fitness = 8
# Chromosome = [1, 3, 1, 2, 2],  Fitness = 7
# Chromosome = [1, 2, 5, 3, 4],  Fitness = 9
# Chromosome = [1, 2, 2, 5, 2],  Fitness = 6
# Chromosome = [1, 3, 4, 5, 4],  Fitness = 8
# Chromosome = [3, 5, 3, 5, 5],  Fitness = 5
# Chromosome = [1, 3, 2, 5, 2],  Fitness = 8
# Chromosome = [5, 4, 4, 3, 1],  Fitness = 8
# Chromosome = [4, 2, 5, 3, 5],  Fitness = 8
# Chromosome = [5, 4, 2, 3, 3],  Fitness = 8
# Chromosome = [4, 4, 5, 5, 2],  Fitness = 7
# Chromosome = [4, 4, 5, 3, 4],  Fitness = 6
# Chromosome = [5, 1, 5, 2, 2],  Fitness = 7
# Chromosome = [5, 3, 5, 3, 3],  Fitness = 5
# Chromosome = [4, 2, 2, 4, 2],  Fitness = 5
# Chromosome = [3, 1, 5, 1, 5],  Fitness = 7
# Chromosome = [4, 5, 5, 4, 2],  Fitness = 6
# Chromosome = [3, 1, 5, 1, 2],  Fitness = 8
# Chromosome = [1, 2, 4, 4, 1],  Fitness = 7
# Chromosome = [3, 2, 5, 2, 1],  Fitness = 8
# Chromosome = [2, 4, 5, 3, 4],  Fitness = 8
# Chromosome = [4, 5, 3, 5, 4],  Fitness = 7
# Chromosome = [1, 5, 1, 3, 5],  Fitness = 7
# Chromosome = [5, 4, 4, 5, 2],  Fitness = 7
# Chromosome = [4, 3, 5, 1, 1],  Fitness = 8
# Chromosome = [3, 1, 4, 5, 3],  Fitness = 8
# Chromosome = [1, 2, 1, 4, 2],  Fitness = 7
# Chromosome = [5, 4, 4, 1, 5],  Fitness = 7
# Chromosome = [2, 2, 2, 5, 2],  Fitness = 3
# Chromosome = [3, 4, 1, 4, 5],  Fitness = 8
# Chromosome = [5, 3, 5, 5, 4],  Fitness = 6
# Chromosome = [3, 2, 4, 3, 4],  Fitness = 7
# Chromosome = [2, 4, 3, 2, 1],  Fitness = 8
# Chromosome = [1, 3, 5, 3, 5],  Fitness = 7
# Chromosome = [4, 3, 2, 1, 5],  Fitness = 9
# Chromosome = [3, 4, 1, 2, 3],  Fitness = 7
# Chromosome = [1, 2, 2, 1, 4],  Fitness = 7
# Chromosome = [1, 2, 5, 2, 1],  Fitness = 7
# Chromosome = [1, 1, 5, 4, 1],  Fitness = 6
# Chromosome = [1, 4, 5, 4, 3],  Fitness = 7
# Chromosome = [2, 1, 1, 4, 1],  Fitness = 6
# Chromosome = [1, 3, 4, 5, 3],  Fitness = 8
# Chromosome = [4, 5, 2, 4, 3],  Fitness = 7
# Chromosome = [5, 4, 5, 3, 5],  Fitness = 6
# Chromosome = [1, 4, 2, 4, 5],  Fitness = 8
# Chromosome = [5, 5, 4, 3, 1],  Fitness = 8
# Chromosome = [5, 4, 3, 2, 3],  Fitness = 8
# Chromosome = [1, 3, 1, 2, 5],  Fitness = 8
# Chromosome = [5, 4, 5, 2, 1],  Fitness = 8
# Chromosome = [1, 3, 4, 3, 1],  Fitness = 7
# Chromosome = [4, 1, 4, 2, 4],  Fitness = 6
# Chromosome = [3, 2, 5, 5, 5],  Fitness = 6
# Chromosome = [5, 4, 4, 3, 5],  Fitness = 7
# Chromosome = [1, 4, 2, 4, 5],  Fitness = 8
# Chromosome = [1, 5, 1, 3, 4],  Fitness = 8
# Chromosome = [3, 4, 1, 1, 1],  Fitness = 6
# Chromosome = [1, 4, 2, 3, 5],  Fitness = 9
# Chromosome = [5, 1, 5, 5, 3],  Fitness = 6
# Chromosome = [5, 3, 5, 4, 2],  Fitness = 8
# Chromosome = [4, 5, 3, 4, 2],  Fitness = 8
# Chromosome = [2, 4, 2, 1, 1],  Fitness = 7
# Chromosome = [4, 1, 5, 2, 3],  Fitness = 9
# Chromosome = [3, 5, 5, 4, 1],  Fitness = 8
# Chromosome = [3, 2, 5, 3, 1],  Fitness = 8
# Chromosome = [4, 2, 2, 4, 5],  Fitness = 7
# Chromosome = [1, 4, 3, 3, 2],  Fitness = 8
# Chromosome = [1, 3, 5, 5, 3],  Fitness = 7
# Chromosome = [2, 4, 4, 5, 2],  Fitness = 7
# Chromosome = [3, 1, 3, 5, 2],  Fitness = 9
# Chromosome = [1, 4, 5, 3, 5],  Fitness = 8
# Chromosome = [2, 4, 3, 5, 3],  Fitness = 8
# Chromosome = [1, 5, 5, 2, 4],  Fitness = 9
# Chromosome = [4, 5, 1, 1, 5],  Fitness = 7
# Chromosome = [1, 2, 2, 5, 3],  Fitness = 8
# Chromosome = [1, 2, 2, 2, 2],  Fitness = 3
# Chromosome = [4, 2, 2, 3, 1],  Fitness = 8
# Chromosome = [2, 2, 1, 4, 4],  Fitness = 7
# Chromosome = [1, 1, 5, 1, 2],  Fitness = 6
# Chromosome = [4, 3, 2, 5, 3],  Fitness = 8
# Chromosome = [5, 1, 3, 4, 4],  Fitness = 8
# Chromosome = [5, 5, 2, 4, 4],  Fitness = 7
# Chromosome = [2, 4, 3, 4, 4],  Fitness = 6
# Chromosome = [5, 3, 1, 1, 1],  Fitness = 6
# Chromosome = [5, 1, 2, 1, 5],  Fitness = 7
#
# Maximum Fitness = 9
# === Generation 2 ===
# Chromosome = [3, 5, 5, 4, 1],  Fitness = 8
# Chromosome = [4, 2, 2, 5, 2],  Fitness = 6
# Chromosome = [5, 3, 5, 3, 5],  Fitness = 6
# Chromosome = [1, 5, 3, 2, 1],  Fitness = 8
# Chromosome = [2, 4, 3, 2, 1],  Fitness = 8
# Chromosome = [2, 2, 1, 4, 5],  Fitness = 8
# Chromosome = [3, 4, 1, 4, 4],  Fitness = 6
# Chromosome = [1, 5, 5, 3, 5],  Fitness = 6
# Chromosome = [1, 4, 3, 5, 3],  Fitness = 8
# Chromosome = [2, 4, 4, 5, 2],  Fitness = 7
# Chromosome = [3, 2, 5, 5, 4],  Fitness = 7
# Chromosome = [1, 4, 5, 4, 4],  Fitness = 6
# Chromosome = [5, 1, 2, 3, 4],  Fitness = 9
# Chromosome = [1, 4, 2, 4, 5],  Fitness = 8
# Chromosome = [2, 4, 2, 2, 1],  Fitness = 6
# Chromosome = [1, 4, 2, 4, 5],  Fitness = 8
# Chromosome = [5, 1, 2, 1, 5],  Fitness = 7
# Chromosome = [1, 4, 5, 5, 2],  Fitness = 8
# Chromosome = [1, 4, 2, 5, 3],  Fitness = 10
#
# Maximum Fitness = 10
# Solved in Generation 2!
#
# One of the solutions:
# Chromosome = [1, 4, 2, 5, 3],  Fitness = 10
#
# x x x Q x
# x Q x x x
# x x x x Q
# x x Q x x
# Q x x x x

# %% [markdown]
# Thus this was solution to N-Queen problem Using Genetic Algorithm. 🌼
